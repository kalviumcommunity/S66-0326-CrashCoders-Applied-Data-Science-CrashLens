# %% [markdown]
# #

# %% [raw]
# x = 5
# print(x)

# %% [raw]
# import time
# while True:
#         time.sleep(1)

# %%
print("Kernel was interrupted safely!")
# Out:
# Kernel was interrupted safely!
