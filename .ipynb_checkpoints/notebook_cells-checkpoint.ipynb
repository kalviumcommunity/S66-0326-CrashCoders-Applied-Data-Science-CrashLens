# %% [markdown]
# # Notebook Purpose
# This notebook explains the difference between Code and Markdown cells. Markdown is for explanations and structure, while Code is for computations.

# %%
# This is a Code cell
print("Code cells execute instructions.")
# Out:
# Code cells execute instructions.

# %% [markdown]
# Markdown is important because it makes notebooks readable for humans!

# %%
print("I can switch types")
# Out:
# I can switch types
