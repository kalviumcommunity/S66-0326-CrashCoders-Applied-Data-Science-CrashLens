# %% [markdown]
# # Data Science Project
# ## Why Documentation Matters
# Documentation is crucial because:
# 1. It explains the intent behind the code.
# 2. It makes notebooks readable for reviewers.
# - This is an unordered list item.

# %% [markdown]
# ### Using Inline Code and Code Blocks
# To run Python, use `print()` inline code.
# Use fenced blocks for bigger segments.

# %%
print("This is actual code execution following our explanation.")
# Out:
# This is actual code execution following our explanation.
