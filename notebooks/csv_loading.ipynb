# %%
#Import
import pandas as pd

# %%
#Load CSV
df = pd.read_csv("../data/raw/sample_data.csv")

print("CSV Loaded Successfully")
# Out:
# CSV Loaded Successfully

# %%
#Preview Data
print(df.head())
# Out:
#        name  age       city
# 0   Khushil   20      Delhi
# 1  Yashasvi   21     Mumbai
# 2      Fiba   22  Bangalore
# 3     Sethu   23    Chennai

# %%
#Inspect Columns
print("Columns:", df.columns)
# Out:
# Columns: Index(['name', 'age', 'city'], dtype='str')

# %%
#Check Shape
print("Shape:", df.shape)
# Out:
# Shape: (4, 3)

# %%
#Check Data Types
print("Data Types:\n", df.dtypes)
# Out:
# Data Types:
#  name      str
# age     int64
# city      str
# dtype: object

# %%
#Check for Issues
print("Missing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  name    0
# age     0
# city    0
# dtype: int64

# %% [markdown]
# Conclusion
#
# CSV files store tabular data in rows and columns.
# After loading, it is important to inspect the data using head(), columns, and shape.
# This helps detect issues early and ensures correct data structure.
